# %%
import netwulf as nw

# %%
result = nw.load('er.json')
result[0]['linkColor'] = '#aaaaaa'
result[0]['linkAlpha'] = 1.0

# %%
fig, ax = nw.draw_netwulf(*result)

# %%
fig.savefig("ER.pdf",dpi=300)

# %%
result = nw.load('expon.json')
result[0]['linkColor'] = '#aaaaaa'
result[0]['linkAlpha'] = 1.0
fig, ax = nw.draw_netwulf(*result)
fig.savefig("expon.pdf",dpi=300)
